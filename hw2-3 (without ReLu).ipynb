# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

batch_size = 4

trainset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform
)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2
)

testset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform
)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2
)

classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(" ".join(f"{classes[labels[j]]:5s}" for j in range(batch_size)))
# Out:
# cat   bird  horse cat

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self, use_relu=False):
        super().__init__()
        self.use_relu = use_relu
        self.fc1 = nn.Linear(32 * 32 * 3, 110)  # 3072 -> 110
        self.fc2 = nn.Linear(110, 74) # 110 -> 74
        self.fc3 = nn.Linear(74, 10) # 74 -> 10

    def forward(self, x):
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        if self.use_relu:
            x = F.relu(x)
        x = self.fc2(x)
        if self.use_relu:
            x = F.relu(x)
        x = self.fc3(x)
        return x


net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
num_epochs = 50
train_losses = []  # To store training losses
train_acc_list = []  # To store training accuracies
test_acc_list = []  # To store test accuracies

for epoch in range(num_epochs):
    running_loss = 0.0  # for mini-batch prints
    epoch_loss = 0.0  # for average epoch loss
    net.train()

    for i, (inputs, labels) in enumerate(trainloader, 0):
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_loss += loss.item()  # accumulate total loss for epoch

        # Print statistics every 2000 mini-batches
        if i % 2000 == 1999:
            print(
                f"[{epoch + 1}, {i + 1:5d}] mini-batch loss: {running_loss / 2000:.3f}"
            )
            running_loss = 0.0

    # Average loss for the epoch
    avg_loss = epoch_loss / len(trainloader)
    train_losses.append(avg_loss)

    # Training accuracy
    correct = 0
    total = 0
    net.eval()
    with torch.no_grad():
        for inputs, labels in trainloader:
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    train_acc = 100 * correct / total
    train_acc_list.append(train_acc)

    # Test accuracy
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in testloader:
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    test_acc = 100 * correct / total
    test_acc_list.append(test_acc)


print("Finished Training")
# Out:
# [1,  2000] mini-batch loss: 1.925
# [1,  4000] mini-batch loss: 1.843
# [1,  6000] mini-batch loss: 1.828
# [1,  8000] mini-batch loss: 1.797
# [1, 10000] mini-batch loss: 1.792
# [1, 12000] mini-batch loss: 1.780
# [2,  2000] mini-batch loss: 1.752
# [2,  4000] mini-batch loss: 1.771
# [2,  6000] mini-batch loss: 1.753
# [2,  8000] mini-batch loss: 1.752
# [2, 10000] mini-batch loss: 1.763
# [2, 12000] mini-batch loss: 1.772
# [3,  2000] mini-batch loss: 1.720
# [3,  4000] mini-batch loss: 1.772
# [3,  6000] mini-batch loss: 1.742
# [3,  8000] mini-batch loss: 1.738
# [3, 10000] mini-batch loss: 1.762
# [3, 12000] mini-batch loss: 1.735
# [4,  2000] mini-batch loss: 1.723
# [4,  4000] mini-batch loss: 1.726
# [4,  6000] mini-batch loss: 1.721
# [4,  8000] mini-batch loss: 1.745
# [4, 10000] mini-batch loss: 1.745
# [4, 12000] mini-batch loss: 1.739
# [5,  2000] mini-batch loss: 1.732
# [5,  4000] mini-batch loss: 1.728
# [5,  6000] mini-batch loss: 1.716
# [5,  8000] mini-batch loss: 1.725
# [5, 10000] mini-batch loss: 1.734
# [5, 12000] mini-batch loss: 1.727
# [6,  2000] mini-batch loss: 1.710
# [6,  4000] mini-batch loss: 1.714
# [6,  6000] mini-batch loss: 1.739
# [6,  8000] mini-batch loss: 1.733
# [6, 10000] mini-batch loss: 1.721
# [6, 12000] mini-batch loss: 1.716
# [7,  2000] mini-batch loss: 1.715
# [7,  4000] mini-batch loss: 1.713
# [43,  8000] mini-batch loss: 1.654
# [43, 10000] mini-batch loss: 1.662
# [43, 12000] mini-batch loss: 1.662
# [44,  2000] mini-batch loss: 1.637
# [44,  4000] mini-batch loss: 1.666
# [44,  6000] mini-batch loss: 1.660
# [44,  8000] mini-batch loss: 1.688
# [44, 10000] mini-batch loss: 1.649
# [44, 12000] mini-batch loss: 1.641
# [45,  2000] mini-batch loss: 1.649
# [45,  4000] mini-batch loss: 1.644
# [45,  6000] mini-batch loss: 1.662
# [45,  8000] mini-batch loss: 1.651
# [45, 10000] mini-batch loss: 1.670
# [45, 12000] mini-batch loss: 1.676
# [46,  2000] mini-batch loss: 1.672
# [46,  4000] mini-batch loss: 1.652
# [46,  6000] mini-batch loss: 1.664
# [46,  8000] mini-batch loss: 1.647
# [46, 10000] mini-batch loss: 1.664
# [46, 12000] mini-batch loss: 1.647
# [47,  2000] mini-batch loss: 1.668
# [47,  4000] mini-batch loss: 1.649
# [47,  6000] mini-batch loss: 1.646
# [47,  8000] mini-batch loss: 1.640
# [47, 10000] mini-batch loss: 1.678
# [47, 12000] mini-batch loss: 1.659
# [48,  2000] mini-batch loss: 1.657
# [48,  4000] mini-batch loss: 1.668
# [48,  6000] mini-batch loss: 1.668
# [48,  8000] mini-batch loss: 1.638
# [48, 10000] mini-batch loss: 1.643
# [48, 12000] mini-batch loss: 1.669
# [49,  2000] mini-batch loss: 1.640
# [49,  4000] mini-batch loss: 1.655
# [49,  6000] mini-batch loss: 1.663
# [49,  8000] mini-batch loss: 1.663
# [49, 10000] mini-batch loss: 1.671
# [49, 12000] mini-batch loss: 1.656
# [50,  2000] mini-batch loss: 1.625
# [50,  4000] mini-batch loss: 1.660
# [50,  6000] mini-batch loss: 1.630
# [50,  8000] mini-batch loss: 1.660
# [50, 10000] mini-batch loss: 1.668
# [50, 12000] mini-batch loss: 1.679
# Finished Training

# %%
PATH = "./cifar_netq3withoutRelu.pth"
torch.save(net.state_dict(), PATH)

# %%
epochs = range(1, num_epochs + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, label="Training Loss")
plt.plot(epochs, train_acc_list, label="Training Accuracy")
plt.plot(epochs, test_acc_list, label="Test Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
plt.show()

# %%
total_params = sum(p.numel() for p in net.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# Total number of parameters: 346994

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print("GroundTruth: ", " ".join(f"{classes[labels[j]]:5s}" for j in range(4)))
# Out:
# GroundTruth:  cat   ship  ship  plane

# %%
net = Net()
net.load_state_dict(torch.load(PATH, weights_only=True))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# <All keys matched successfully>

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print("Predicted: ", " ".join(f"{classes[predicted[j]]:5s}" for j in range(4)))
# Out:
# Predicted:  cat   ship  ship  bird

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy of the network on the 10000 test images: {100 * correct // total} %")
# Out:
# Accuracy of the network on the 10000 test images: 38 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f"Accuracy for class: {classname:5s} is {accuracy:.1f} %")
# Out:
# Accuracy for class: plane is 53.5 %
# Accuracy for class: car   is 31.9 %
# Accuracy for class: bird  is 24.4 %
# Accuracy for class: cat   is 25.6 %
# Accuracy for class: deer  is 23.7 %
# Accuracy for class: dog   is 27.0 %
# Accuracy for class: frog  is 57.6 %
# Accuracy for class: horse is 42.6 %
# Accuracy for class: ship  is 54.1 %
# Accuracy for class: truck is 42.9 %

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu
